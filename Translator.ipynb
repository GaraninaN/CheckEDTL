# %% [markdown]
# <a href="https://colab.research.google.com/github/GaraninaN/CheckEDTL/blob/main/Translator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def disSimpl(a, b):
  if (a == True) or (b == True): return True;
  elif (a == False): return b;
  elif (b == False): return a;
  #a ∨ a = a
  elif ((type(a) != type(True)) and (type(b) != type(True)) and (a == b)):
    return a;
  #a ∨ (b ∧ (a ∨ c)) = a ∨ (b ∧ c)
  elif (b.find('∧ ('+a+' ∨ ') >= 0):
    b2 = b.replace('('+a+' ∨ ', '');
    b2 = b2.replace( ')', '', 1);
    return '(' +a+ ' ∨ ' +b2+ ')';
  #a ∨ F(a ∨ b) = F(a ∨ b)
  elif (b.find('F('+a+' ∨ ') >= 0): 
    return b;
  #a ∨ (b U a) = (b U a)
  elif ((b[0:1] == '(') and (b.find (' U '+a+')') >= 0)): 
    return b;
  #G(¬a) ∨ F(a) = true
  elif ((a[0:3] == 'G(¬') and (b[0:2] == 'F(') and (a[3:] == b[2:])): 
    return True;
  #a ∨ F(a) = F(a)
  elif ((b[0:2] == 'F(') and (b[2:-1] == a)): 
    return b;
  elif (b.find(' ∧ '+a+')') > 0): 
    return a;
  #a ∨ (a ∨ b) = a V b | a ∨ (b ∨ a) = a ∨ b
  elif (b.find('('+a+' ∨ ') == 0): 
    return b;

  #G(¬a) ∨ (F(a) ∨ (с)) = (с)
  elif ((a[0:3] == 'G(¬') and (b[0:3] == '(F(') and (a[3:-1] == b[3:len(a[3:-1])+3]) and (b.find(') ∨ (') == len(a[3:-1])+3)): 
    return b[len(a[3:-1])+7:-1];

  #a ∨ (b U (a ∨ c)) = (b U (a ∨ c))
  elif (b.find(' U (' + a + ' ∨ ') > 0):
    return b;

  else: 
    return '(' +a+ ' ∨ ' +b+ ')'

# %%
def conSimpl(a, b):
  if (a == False) or (b == False): return False;
  elif (a == True): return b;
  elif (b == True): return a;
  
  else: return '('+a+' ∧ '+b+')'

# %%
def no(a):
  if (type(a) == type(True)): return not a;
  
  else: return "¬" + a;

# %%
def implSimpl(a, b):
  if ((type(a) == type(True)) or (type(b) == type(True))): return disSimpl(no(a),b);

  else:  return '('+a+' → '+b+')'

# %%
def FutureSimpl(a):
  if (type(a) == type(True)): return a;
  elif (a[0] != '('): return 'F('+a+')';
  else: return 'F'+a+''

# %%
def GloballySimpl(a):
  if (type(a) == type(True)): return a;
  #G(F(a)) = GF(a)
  elif ((a[0] == 'F') and (a[1] == '(') and (a[len(a)-1] == ')')): 
    return 'G'+a;
  #G(G(a)) = G(a)
  elif ((a[0] == 'G')and (a[1] == '(') and (a[len(a)-1] == ')')): 
    return a;

  #51 G(G(a ∧ ¬b) ∨ (a U (b ∧ a))) = G(a)
  elif((a[:3] == '(G(') and (a.find(' ∧ ¬') > 0) and (a.find(') ∨ (') > a.find(' ∧ ¬'))
        and (a.find(a[3:a.find(' ∧ ¬')] + ' U (') > 0)
        and (a.find(a[a.find(' ∧ ¬')+4:a.find(') ∨ (')] + ' ∧ ' + a[3:a.find(' ∧ ¬')]) > 0)):
    return 'G(' + a[3:a.find(' ∧ ¬')] + ')';

  #52 G(G(a ∧ ¬b) ∨ ((a ∧ ¬b) U (b ∧ (a U (a ∧ c))))) = G(a ∧ (G(¬b) ∨ F(b ∧ F(c))))
  elif((a[:3] == '(G(') and (a.find(' ∧ ¬') > 0) and (a.find(') ∨ (') > a.find(' ∧ ¬'))
        and (a.find(a[3:(a.find(') ∨ ('))] + ') U (' + a[a.find(' ∧ ¬')+4:a.find(') ∨ (')] +
                    ' ∧ (' + a[3:a.find(' ∧ ¬')] + ' U (' + a[3:a.find(' ∧ ¬')] + ' ∧ ') > a.find(') ∨ (')) ):
    a1 = a[3:a.find(' ∧ ¬')];
    nb1 = a[a.find(' ∧ ¬')+3:a.find(') ∨ (')]
    b1 = a[a.find(' ∧ ¬')+4:a.find(') ∨ (')]
    
    n ='G(' + a[3:a.find(' ∧ ¬')] + ' ∧ ¬' + a[a.find(' ∧ ¬')+4:a.find(') ∨ (')] + ') ∨ ((' + a[3:(a.find(') ∨ ('))] + ') U (' + a[a.find(' ∧ ¬')+4:a.find(') ∨ (')] + ' ∧ (' + a[3:a.find(' ∧ ¬')] + ' U (' + a[3:a.find(' ∧ ¬')] + ' ∧ '
    t = a.find(n)
    tlen = len(n)
    c = a[tlen + 1:-5]

    return 'G' + conSimpl(a1, disSimpl(GloballySimpl(nb1), FutureSimpl(disSimpl(b1, FutureSimpl(c)))))

  #53 G(G(a ∧ ¬b) ∨ ((a ∧ ¬b) U (b ∧ (a ∧ c)))) = G(a ∧ (G(¬b) ∨ F(b ∧ c)))
  elif((a[:3] == '(G(') and (a.find(' ∧ ¬') > 0) and (a.find(') ∨ (') > a.find(' ∧ ¬'))
        and (a.find(a[3:(a.find(') ∨ ('))] + ') U (' + a[a.find(' ∧ ¬')+4:a.find(') ∨ (')] +
                    ' ∧ (' + a[3:a.find(' ∧ ¬')] + ' ∧ ') > a.find(') ∨ (')) ):
    a1 = a[3:a.find(' ∧ ¬')];
    nb1 = a[a.find(' ∧ ¬')+3:a.find(') ∨ (')]
    b1 = a[a.find(' ∧ ¬')+4:a.find(') ∨ (')]

    n ='G(' + a[3:a.find(' ∧ ¬')] + ' ∧ ¬' + a[a.find(' ∧ ¬')+4:a.find(') ∨ (')] + ') ∨ ((' + a[3:(a.find(') ∨ ('))] + ') U (' + a[a.find(' ∧ ¬')+4:a.find(') ∨ (')] + ' ∧ (' + a[3:a.find(' ∧ ¬')] + ' ∧ '
    t = a.find(n)
    tlen = len(n)
    c = a[tlen + 1:-4]

    return 'G' + conSimpl(a1, disSimpl(GloballySimpl(nb1), FutureSimpl(disSimpl(b1, c))));

  #44 G(G(a) ∨ (a U b)) = G(a ∧ F(b))
  elif ((a[0:3] == '(G(') and (a.find(') ∨ (') > 0) and (a.find(a[3:a.find(') ∨ (')] + ' U '))):
    return GloballySimpl(conSimpl(a[3:a.find(') ∨ (')], FutureSimpl(a[a.find(' U ')+3:-2])))
  
  #45 G((a ∧ b) U (a ∧ c)) = G(a ∧ (b U c))
  elif ((a[0:2] == '((') and (a.find(' ∧ ') > 0) and (a.find(') U (') > a.find(' ∧ ')) 
          and (a[2:a.find(' ∧ ')] == a[a.find(') U (')+5:a.find(' ∧ ', a.find(' ∧ ') + 1)])):
    b = a[a.find(' ∧ ') + 3: a.find(') U (')]
    c = a[a.find(' ∧ ', a.find(' ∧ ') + 1) + 3:-2]
    a1 = a[2:a.find(' ∧ ')]   
    return GloballySimpl(conSimpl(a1, UntilSimpl(b,c)));
    
  elif (a[0] != '('): return 'G('+a+')';
  else: return 'G'+a;

# %%
def UntilSimpl(a, b):
  if (b == False): return False;
  elif (b == True): return True;
  elif ((a == False) and (type(b) != type(True))): return b;
  elif ((a == True) and (type(b) != type(True))): return FutureSimpl(b);

  #a U a = a
  elif (a == b):
    return a;

  # ¬a U a = F(a)
  elif((a.find('¬') == 0) and (b == a[1:])):
    return FutureSimpl(b);

  #¬a U (b ∨ a) = F(a) ∨ (¬a U b)
  elif ((a[0] == '¬') and (b.find ('∨ ' + a[1:]) > 0)):
    b1 = b[1:(b.find ('∨ ' + a[1:]))-1];
    return disSimpl(FutureSimpl(a[1:]), UntilSimpl(a, b1));

  #46 (a ∧ b) U (c ∨ a) = a ∨ ((a ∧ b) U c)
  elif ((a.find(' ∧ ') > 0) and (b.find(' ∨ ') > 0) and (a[1:a.find(' ∧ ')] == b[b.find(' ∨ ')+3:-1])):
    c = UntilSimpl(a, b[1:b.find(' ∨ ')]);
    return disSimpl(a[1:a.find(' ∧ ')], c);

  #47 (a ∧ b) U a = a
  elif(a.find('(' + b + ' ∧ ') == 0):
    return b;

  #48 a U (b ∨ a) = a ∨ (a U b)
  elif (b.find(' ∨ ' + a + ')') > 0):
    return disSimpl(a, UntilSimpl(a, b[1:b.find(' ∨ ')]));

  #50 (a ∧ ¬b) U (b ∧ a) = a U (b ∧ a)
  elif ((a.find(' ∧ ') > 0) and (b.find(' ∧ ') > 0) 
        and (a[1:a.find(' ∧ ')] == b[b.find(' ∧ ')+3:-1])
        and (a[a.find(' ∧ ')+3] == '¬') 
        and (b[1:b.find(' ∧ ')] == a[a.find(' ∧ ')+4:-1])):
    return UntilSimpl(a[1:a.find(' ∧ ')], b)

  else: return '('+a+' U '+b+')'

# %%
def WeakUntil(a, b):
  if ((type(a) == type(True)) and (type(b) == type(True))):
    if ((a == False) and (b == False)): return False;
    else: return True;
  elif ((type(b) != type(True)) and (type(a) != type(True))): return '('+a+' W '+b+')';
  elif (type(b) != type(True)):
    if (a == False): return b;
    elif (a == True): return True;
  elif (type(a) != type(True)):
    if (b == True): return True;
    elif (b == False): return GloballySimpl(a);

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt 

data_frame = pd.read_csv('atributs.csv', encoding='utf8')

data_frame
# Out:
#     release   delay  final reaction invariant
# 0       rel     del    fin      rea       inv
# 1     true*     del    fin      rea       inv
# 2    false*     del    fin      rea       inv
# 3    false*   true*    fin      rea       inv
# 4    false*  false*    fin      rea       inv
# ..      ...     ...    ...      ...       ...
# 238   true*  false*  true*      rea     true*
# 239   true*  false*  true*      rea    false*
# 240   true*  false*  true*   false*       inv
# 241   true*  false*  true*   false*     true*
# 242   true*  false*  true*   false*    false*
#
# [243 rows x 5 columns]

# %%
def konv(a_txt):
  if (a_txt == 'true*'): return True;
  elif (a_txt == 'false*'): return False;
  else: return a_txt;

# %%
def BoolToString(a):
  if (type(a) == type(True)): 
    if (a == True): return "true";
    elif (a == False): return "false";
  else: return a;

# %%
a = 12
mas = [] 
for i1 in range(243): 
    mas.append([0] * a)


for i in data_frame.index:
  release_txt = data_frame['release'][i]
  delay_txt = data_frame['delay'][i]
  final_txt =  data_frame['final'][i]
  reaction_txt =  data_frame['reaction'][i]
  invariant_txt =  data_frame['invariant'][i]

  release = konv(release_txt);
  delay = konv(delay_txt);
  final = konv(final_txt);
  reaction = konv(reaction_txt);
  invariant = konv(invariant_txt);

  trigger = 'trig'
  x0 = conSimpl(trigger, no(release));
  x1 = conSimpl(invariant, reaction);
  x2 = disSimpl(release, x1);
  x3 = conSimpl(invariant, no(delay));
  x4 = UntilSimpl(x3, x2);
  x5 = conSimpl(final, x4);
  x6 = disSimpl(release, x5)
  x7 = conSimpl(invariant, no(final));
  x8 = UntilSimpl(x7, x6);

  x9 = conSimpl(invariant, no(final));
  x10 = GloballySimpl(x9);
  x11 = disSimpl(x10, x8);
  x12 = conSimpl(invariant, x11);
  x13 = implSimpl(x0, x12);
  x14 = GloballySimpl(x13);

  
  trigger = True
  
  y0 = conSimpl(trigger, no(release));
  y1 = conSimpl(invariant, reaction);
  y2 = disSimpl(release, y1);
  y3 = conSimpl(invariant, no(delay));
  y4 = UntilSimpl(y3, y2);
  y5 = conSimpl(final, y4);
  y6 = disSimpl(release, y5)
  y7 = conSimpl(invariant, no(final));
  y8 = UntilSimpl(y7, y6);
  y9 = conSimpl(invariant, no(final));

  y10 = GloballySimpl(y9);
  y11 = disSimpl(y10, y8);
  y12 = conSimpl(invariant, y11);
  y13 = implSimpl(y0, y12);
  y14 = GloballySimpl(y13);

  trigger = False
  z1 = True;
  
  mas[i][0]=BoolToString(release);
  mas[i][1]=BoolToString(delay);
  mas[i][2]=BoolToString(final);
  mas[i][3]=BoolToString(reaction);
  mas[i][4]=BoolToString(invariant);

  mas[i][5]=BoolToString(x14);
  mas[i][6]=BoolToString(y14);
  mas[i][7]=BoolToString(z1);

for i in range(0, len(mas)):
    for i2 in range(0, len(mas[i])):
        print(mas[i][i2], end=' ')
    print()


from openpyxl import Workbook
wb = Workbook()
ws = wb.active


for subarray in mas:
    ws.append(subarray)
wb.save('./edtl-ltl.xlsx')
# Out:
# rel del fin rea inv G((trig ∧ ¬rel) → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ ((inv ∧ ¬del) U (rel ∨ (inv ∧ rea)))))))) G(¬rel → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ ((inv ∧ ¬del) U (rel ∨ (inv ∧ rea)))))))) true 0 0 0 0
# true del fin rea inv true true true 0 0 0 0
# false del fin rea inv G(trig → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ ((inv ∧ ¬del) U (inv ∧ rea))))))) G(inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ ((inv ∧ ¬del) U (inv ∧ rea)))))) true 0 0 0 0
# false true fin rea inv G(trig → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ (inv ∧ rea)))))) G(inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ (inv ∧ rea))))) true 0 0 0 0
# false false fin rea inv G(trig → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ (inv U (inv ∧ rea))))))) G(inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ (inv U (inv ∧ rea)))))) true 0 0 0 0
# false del true rea inv G(trig → (inv ∧ ((inv ∧ ¬del) U (inv ∧ rea)))) G(inv ∧ ((inv ∧ ¬del) U (inv ∧ rea))) true 0 0 0 0
# false true true rea inv G(trig → (inv ∧ (inv ∧ rea))) G(inv ∧ (inv ∧ rea)) true 0 0 0 0
# false false true rea inv G(trig → (inv ∧ (inv U (inv ∧ rea)))) G(inv ∧ (inv U (inv ∧ rea))) true 0 0 0 0
# false del fin true inv G(trig → (inv ∧ (G(inv ∧ ¬fin) ∨ (inv U (fin ∧ inv))))) G(inv ∧ (G(inv ∧ ¬fin) ∨ (inv U (fin ∧ inv)))) true 0 0 0 0
# false del true true inv G(trig → (inv ∧ inv)) G(inv ∧ inv) true 0 0 0 0
# false del fin rea true G(trig → (G(¬fin) ∨ (¬fin U (fin ∧ (¬del U rea))))) G(¬fin ∧ F(fin ∧ (¬del U rea))) true 0 0 0 0
# false true fin rea true G(trig → (G(¬fin) ∨ (¬fin U (fin ∧ rea)))) G(¬fin ∧ F(fin ∧ rea)) true 0 0 0 0
# false false fin rea true G(trig → (G(¬fin) ∨ (¬fin U (fin ∧ F(rea))))) G(¬fin ∧ F(fin ∧ F(rea))) true 0 0 0 0
# false del true rea true G(trig → (¬del U rea)) G(¬del U rea) true 0 0 0 0
# false true true rea true G(trig → rea) G(rea) true 0 0 0 0
# false false true rea true G(trig → F(rea)) GF(rea) true 0 0 0 0
# false del fin true true true true true 0 0 0 0
# false true fin true true true true true 0 0 0 0
# false false fin true true true true true 0 0 0 0
# false del true true true true true true 0 0 0 0
# false true true true true true true true 0 0 0 0
# false false true true true true true true 0 0 0 0
# false del false true true true true true 0 0 0 0
# false true false true true true true true 0 0 0 0
# false false false true true true true true 0 0 0 0
# false del fin rea false G(¬trig) false true 0 0 0 0
# false del fin true false G(¬trig) false true 0 0 0 0
# false del fin false false G(¬trig) false true 0 0 0 0
# false del true rea false G(¬trig) false true 0 0 0 0
# false del true true false G(¬trig) false true 0 0 0 0
# false del true false false G(¬trig) false true 0 0 0 0
# false del false rea false G(¬trig) false true 0 0 0 0
# false del false true false G(¬trig) false true 0 0 0 0
# false del false false false G(¬trig) false true 0 0 0 0
# false true fin rea false G(¬trig) false true 0 0 0 0
# false true fin true false G(¬trig) false true 0 0 0 0
# false true fin false false G(¬trig) false true 0 0 0 0
# false true true rea false G(¬trig) false true 0 0 0 0
# false true true true false G(¬trig) false true 0 0 0 0
# false true true false false G(¬trig) false true 0 0 0 0
# false true false rea false G(¬trig) false true 0 0 0 0
# false true false true false G(¬trig) false true 0 0 0 0
# false true false false false G(¬trig) false true 0 0 0 0
# false false fin rea false G(¬trig) false true 0 0 0 0
# false false fin true false G(¬trig) false true 0 0 0 0
# false false fin false false G(¬trig) false true 0 0 0 0
# false false true rea false G(¬trig) false true 0 0 0 0
# false false true true false G(¬trig) false true 0 0 0 0
# false false true false false G(¬trig) false true 0 0 0 0
# false false false rea false G(¬trig) false true 0 0 0 0
# false false false true false G(¬trig) false true 0 0 0 0
# false false false false false G(¬trig) false true 0 0 0 0
# rel del false rea inv G((trig ∧ ¬rel) → (inv ∧ (G(inv) ∨ (inv U rel)))) G(¬rel → (inv ∧ (G(inv) ∨ (inv U rel)))) true 0 0 0 0
# rel del false true inv G((trig ∧ ¬rel) → (inv ∧ (G(inv) ∨ (inv U rel)))) G(¬rel → (inv ∧ (G(inv) ∨ (inv U rel)))) true 0 0 0 0
# rel del false false inv G((trig ∧ ¬rel) → (inv ∧ (G(inv) ∨ (inv U rel)))) G(¬rel → (inv ∧ (G(inv) ∨ (inv U rel)))) true 0 0 0 0
# rel true false rea inv G((trig ∧ ¬rel) → (inv ∧ (G(inv) ∨ (inv U rel)))) G(¬rel → (inv ∧ (G(inv) ∨ (inv U rel)))) true 0 0 0 0
# rel true false true inv G((trig ∧ ¬rel) → (inv ∧ (G(inv) ∨ (inv U rel)))) G(¬rel → (inv ∧ (G(inv) ∨ (inv U rel)))) true 0 0 0 0
# rel true false false inv G((trig ∧ ¬rel) → (inv ∧ (G(inv) ∨ (inv U rel)))) G(¬rel → (inv ∧ (G(inv) ∨ (inv U rel)))) true 0 0 0 0
# rel false false rea inv G((trig ∧ ¬rel) → (inv ∧ (G(inv) ∨ (inv U rel)))) G(¬rel → (inv ∧ (G(inv) ∨ (inv U rel)))) true 0 0 0 0
# rel false false true inv G((trig ∧ ¬rel) → (inv ∧ (G(inv) ∨ (inv U rel)))) G(¬rel → (inv ∧ (G(inv) ∨ (inv U rel)))) true 0 0 0 0
# rel false false false inv G((trig ∧ ¬rel) → (inv ∧ (G(inv) ∨ (inv U rel)))) G(¬rel → (inv ∧ (G(inv) ∨ (inv U rel)))) true 0 0 0 0
# true del false rea inv true true true 0 0 0 0
# true del false rea true true true true 0 0 0 0
# true del false rea false true true true 0 0 0 0
# true del false true inv true true true 0 0 0 0
# true del false true true true true true 0 0 0 0
# true del false true false true true true 0 0 0 0
# true del false false inv true true true 0 0 0 0
# true del false false true true true true 0 0 0 0
# true del false false false true true true 0 0 0 0
# true true false rea inv true true true 0 0 0 0
# true true false rea true true true true 0 0 0 0
# true true false rea false true true true 0 0 0 0
# true true false true inv true true true 0 0 0 0
# true true false true true true true true 0 0 0 0
# true true false true false true true true 0 0 0 0
# true true false false inv true true true 0 0 0 0
# true true false false true true true true 0 0 0 0
# true true false false false true true true 0 0 0 0
# true false false rea inv true true true 0 0 0 0
# true false false rea true true true true 0 0 0 0
# true false false rea false true true true 0 0 0 0
# true false false true inv true true true 0 0 0 0
# true false false true true true true true 0 0 0 0
# true false false true false true true true 0 0 0 0
# true false false false inv true true true 0 0 0 0
# true false false false true true true true 0 0 0 0
# true false false false false true true true 0 0 0 0
# false del false rea inv G(trig → (inv ∧ G(inv))) G(inv ∧ G(inv)) true 0 0 0 0
# false del false true inv G(trig → (inv ∧ G(inv))) G(inv ∧ G(inv)) true 0 0 0 0
# false del false false inv G(trig → (inv ∧ G(inv))) G(inv ∧ G(inv)) true 0 0 0 0
# false true false rea inv G(trig → (inv ∧ G(inv))) G(inv ∧ G(inv)) true 0 0 0 0
# false true false true inv G(trig → (inv ∧ G(inv))) G(inv ∧ G(inv)) true 0 0 0 0
# false true false false inv G(trig → (inv ∧ G(inv))) G(inv ∧ G(inv)) true 0 0 0 0
# false false false rea inv G(trig → (inv ∧ G(inv))) G(inv ∧ G(inv)) true 0 0 0 0
# false false false true inv G(trig → (inv ∧ G(inv))) G(inv ∧ G(inv)) true 0 0 0 0
# false false false false inv G(trig → (inv ∧ G(inv))) G(inv ∧ G(inv)) true 0 0 0 0
# false del false rea true true true true 0 0 0 0
# false del false false true true true true 0 0 0 0
# false true false rea true true true true 0 0 0 0
# false true false false true true true true 0 0 0 0
# false false false rea true true true true 0 0 0 0
# false false false false true true true true 0 0 0 0
# rel del false rea true true true true 0 0 0 0
# rel del false true true true true true 0 0 0 0
# rel del false false true true true true 0 0 0 0
# rel true false rea true true true true 0 0 0 0
# rel true false true true true true true 0 0 0 0
# rel true false false true true true true 0 0 0 0
# rel false false rea true true true true 0 0 0 0
# rel false false true true true true true 0 0 0 0
# rel false false false true true true true 0 0 0 0
# rel del false rea false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel del false true false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel del false false false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel true false rea false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel true false true false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel true false false false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel false false rea false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel false false true false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel false false false false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel del true rea inv G((trig ∧ ¬rel) → (inv ∧ ((inv ∧ ¬del) U (rel ∨ (inv ∧ rea))))) G(¬rel → (inv ∧ ((inv ∧ ¬del) U (rel ∨ (inv ∧ rea))))) true 0 0 0 0
# rel true true rea inv G((trig ∧ ¬rel) → (inv ∧ (rel ∨ (inv ∧ rea)))) G(¬rel → (inv ∧ (rel ∨ (inv ∧ rea)))) true 0 0 0 0
# rel false true rea inv G((trig ∧ ¬rel) → (inv ∧ (inv U (rel ∨ (inv ∧ rea))))) G(¬rel → (inv ∧ (inv U (rel ∨ (inv ∧ rea))))) true 0 0 0 0
# rel false true rea true G((trig ∧ ¬rel) → F(rel ∨ rea)) G(¬rel → F(rel ∨ rea)) true 0 0 0 0
# rel false true rea false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel del true true inv G((trig ∧ ¬rel) → (inv ∧ (inv ∨ ((inv ∧ ¬del) U rel)))) G(¬rel → (inv ∧ (inv ∨ ((inv ∧ ¬del) U rel)))) true 0 0 0 0
# rel del true true true true true true 0 0 0 0
# rel true true true inv G((trig ∧ ¬rel) → (inv ∧ (rel ∨ inv))) G(¬rel → (inv ∧ (rel ∨ inv))) true 0 0 0 0
# rel true true true true true true true 0 0 0 0
# rel false true true inv G((trig ∧ ¬rel) → (inv ∧ (inv ∨ (inv U rel)))) G(¬rel → (inv ∧ (inv ∨ (inv U rel)))) true 0 0 0 0
# rel false true true true true true true 0 0 0 0
# false true true true inv G(trig → (inv ∧ inv)) G(inv ∧ inv) true 0 0 0 0
# false false true true inv G(trig → (inv ∧ inv)) G(inv ∧ inv) true 0 0 0 0
# true del true true inv true true true 0 0 0 0
# true del true true true true true true 0 0 0 0
# true del true true false true true true 0 0 0 0
# true true true true inv true true true 0 0 0 0
# true true true true true true true true 0 0 0 0
# true true true true false true true true 0 0 0 0
# true false true true inv true true true 0 0 0 0
# true false true true true true true true 0 0 0 0
# true false true true false true true true 0 0 0 0
# rel del true true false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel true true true false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel false true true false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel del true false inv G((trig ∧ ¬rel) → (inv ∧ ((inv ∧ ¬del) U rel))) G(¬rel → (inv ∧ ((inv ∧ ¬del) U rel))) true 0 0 0 0
# rel false true false inv G((trig ∧ ¬rel) → (inv ∧ (inv U rel))) G(¬rel → (inv ∧ (inv U rel))) true 0 0 0 0
# rel false true false true G((trig ∧ ¬rel) → F(rel)) G(¬rel → F(rel)) true 0 0 0 0
# rel false true false false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel true true false inv G((trig ∧ ¬rel) → (inv ∧ rel)) G(¬rel → (inv ∧ rel)) true 0 0 0 0
# rel del true rea false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel del true false false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel true true rea false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel true true false false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel del true rea true G((trig ∧ ¬rel) → (¬del U (rel ∨ rea))) G(¬rel → (¬del U (rel ∨ rea))) true 0 0 0 0
# rel true true rea true G((trig ∧ ¬rel) → (rel ∨ rea)) G(¬rel → (rel ∨ rea)) true 0 0 0 0
# rel del true false true G((trig ∧ ¬rel) → (¬del U rel)) G(¬rel → (¬del U rel)) true 0 0 0 0
# rel true true false true G((trig ∧ ¬rel) → rel) G(¬rel → rel) true 0 0 0 0
# rel true fin rea inv G((trig ∧ ¬rel) → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (rel ∨ (fin ∧ (inv ∧ rea))))))) G(¬rel → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (rel ∨ (fin ∧ (inv ∧ rea))))))) true 0 0 0 0
# rel true fin rea true G((trig ∧ ¬rel) → (G(¬fin) ∨ (¬fin U (rel ∨ (fin ∧ rea))))) G(¬rel → (G(¬fin) ∨ (¬fin U (rel ∨ (fin ∧ rea))))) true 0 0 0 0
# rel true fin rea false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel true fin true inv G((trig ∧ ¬rel) → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (rel ∨ (fin ∧ inv)))))) G(¬rel → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (rel ∨ (fin ∧ inv)))))) true 0 0 0 0
# rel true fin true true G((trig ∧ ¬rel) → (¬fin U rel)) G(¬rel → (¬fin U rel)) true 0 0 0 0
# rel true fin true false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel true fin false inv G((trig ∧ ¬rel) → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U rel)))) G(¬rel → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U rel)))) true 0 0 0 0
# rel true fin false false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel true fin false true G((trig ∧ ¬rel) → (G(¬fin) ∨ (¬fin U rel))) G(¬rel → (G(¬fin) ∨ (¬fin U rel))) true 0 0 0 0
# rel false fin rea inv G((trig ∧ ¬rel) → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ (inv U (rel ∨ (inv ∧ rea)))))))) G(¬rel → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ (inv U (rel ∨ (inv ∧ rea)))))))) true 0 0 0 0
# rel false fin rea true G((trig ∧ ¬rel) → (G(¬fin) ∨ (¬fin U (fin ∧ F(rel ∨ rea))))) G(¬rel → (G(¬fin) ∨ (¬fin U (fin ∧ F(rel ∨ rea))))) true 0 0 0 0
# rel false fin rea false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel false fin true inv G((trig ∧ ¬rel) → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ (inv ∨ (inv U rel))))))) G(¬rel → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ (inv ∨ (inv U rel))))))) true 0 0 0 0
# rel false fin true true G((trig ∧ ¬rel) → (¬fin U rel)) G(¬rel → (¬fin U rel)) true 0 0 0 0
# rel false fin true false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel false fin false inv G((trig ∧ ¬rel) → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ (inv U rel)))))) G(¬rel → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ (inv U rel)))))) true 0 0 0 0
# rel del fin rea true G((trig ∧ ¬rel) → (G(¬fin) ∨ (¬fin U (fin ∧ (¬del U (rel ∨ rea)))))) G(¬rel → (G(¬fin) ∨ (¬fin U (fin ∧ (¬del U (rel ∨ rea)))))) true 0 0 0 0
# rel del fin rea false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel del fin true inv G((trig ∧ ¬rel) → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ (inv ∨ ((inv ∧ ¬del) U rel))))))) G(¬rel → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ (inv ∨ ((inv ∧ ¬del) U rel))))))) true 0 0 0 0
# rel del fin true true G((trig ∧ ¬rel) → (¬fin U rel)) G(¬rel → (¬fin U rel)) true 0 0 0 0
# rel del fin true false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel del fin false inv G((trig ∧ ¬rel) → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ ((inv ∧ ¬del) U rel)))))) G(¬rel → (inv ∧ (G(inv ∧ ¬fin) ∨ ((inv ∧ ¬fin) U (fin ∧ ((inv ∧ ¬del) U rel)))))) true 0 0 0 0
# rel del fin false false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# rel del fin false true G((trig ∧ ¬rel) → (G(¬fin) ∨ (¬fin U (fin ∧ (¬del U rel))))) G(¬rel → (G(¬fin) ∨ (¬fin U (fin ∧ (¬del U rel))))) true 0 0 0 0
# false true true false true G(¬trig) false true 0 0 0 0
# true true true rea true true true true 0 0 0 0
# true true true false true true true true 0 0 0 0
# true del true rea true true true true 0 0 0 0
# true del true false true true true true 0 0 0 0
# true false fin rea true true true true 0 0 0 0
# true false fin true true true true true 0 0 0 0
# true false fin false true true true true 0 0 0 0
# false false fin false true G(trig → G(¬fin)) G(¬fin) true 0 0 0 0
# true true fin true true true true true 0 0 0 0
# true true fin false true true true true 0 0 0 0
# true true fin rea true true true true 0 0 0 0
# false true fin true inv G(trig → (inv ∧ (G(inv ∧ ¬fin) ∨ (inv U (fin ∧ inv))))) G(inv ∧ (G(inv ∧ ¬fin) ∨ (inv U (fin ∧ inv)))) true 0 0 0 0
# false true fin false inv G(trig → (inv ∧ G(inv ∧ ¬fin))) G(inv ∧ G(inv ∧ ¬fin)) true 0 0 0 0
# false false fin true inv G(trig → (inv ∧ (G(inv ∧ ¬fin) ∨ (inv U (fin ∧ inv))))) G(inv ∧ (G(inv ∧ ¬fin) ∨ (inv U (fin ∧ inv)))) true 0 0 0 0
# false false fin false inv G(trig → (inv ∧ G(inv ∧ ¬fin))) G(inv ∧ G(inv ∧ ¬fin)) true 0 0 0 0
# false del fin false inv G(trig → (inv ∧ G(inv ∧ ¬fin))) G(inv ∧ G(inv ∧ ¬fin)) true 0 0 0 0
# false del fin false true G(trig → G(¬fin)) G(¬fin) true 0 0 0 0
# false true fin false true G(trig → G(¬fin)) G(¬fin) true 0 0 0 0
# rel false fin false true G((trig ∧ ¬rel) → (G(¬fin) ∨ (¬fin U (rel ∨ (fin ∧ F(rel)))))) G(¬rel → (G(¬fin) ∨ (¬fin U (rel ∨ (fin ∧ F(rel)))))) true 0 0 0 0
# true true true false inv true true true 0 0 0 0
# true true true rea inv true true true 0 0 0 0
# true del true rea inv true true true 0 0 0 0
# true del true false inv true true true 0 0 0 0
# true false fin rea inv true true true 0 0 0 0
# true false fin true inv true true true 0 0 0 0
# true false fin false inv true true true 0 0 0 0
# true del fin rea true true true true 0 0 0 0
# true del fin true true true true true 0 0 0 0
# true del fin false true true true true 0 0 0 0
# true true fin rea inv true true true 0 0 0 0
# true true fin true inv true true true 0 0 0 0
# true true fin false inv true true true 0 0 0 0
# true del fin true inv true true true 0 0 0 0
# true del fin false inv true true true 0 0 0 0
# rel false fin false false G(¬(trig ∧ ¬rel)) G(¬¬rel) true 0 0 0 0
# false del true false inv G(¬trig) false true 0 0 0 0
# false del true false true G(¬trig) false true 0 0 0 0
# false true true false inv G(¬trig) false true 0 0 0 0
# false false true false inv G(¬trig) false true 0 0 0 0
# false false true false true G(¬trig) false true 0 0 0 0
# true del fin rea false true true true 0 0 0 0
# true del fin true false true true true 0 0 0 0
# true del fin false false true true true 0 0 0 0
# true del true rea false true true true 0 0 0 0
# true del true false false true true true 0 0 0 0
# true true fin rea false true true true 0 0 0 0
# true true fin true false true true true 0 0 0 0
# true true fin false false true true true 0 0 0 0
# true true true rea false true true true 0 0 0 0
# true true true false false true true true 0 0 0 0
# true false fin rea false true true true 0 0 0 0
# true false fin true false true true true 0 0 0 0
# true false fin false false true true true 0 0 0 0
# true false true rea inv true true true 0 0 0 0
# true false true rea true true true true 0 0 0 0
# true false true rea false true true true 0 0 0 0
# true false true false inv true true true 0 0 0 0
# true false true false true true true true 0 0 0 0
# true false true false false true true true 0 0 0 0
